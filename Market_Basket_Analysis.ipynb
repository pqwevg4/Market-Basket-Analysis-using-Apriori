# %%
#Loading necessary packages

import numpy as np
import pandas as pd
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %%
#Reading Data
myretaildata = pd.read_csv('/content/Groceries_dataset.csv')
myretaildata.head()
# Out:
#    Member_number        Date   itemDescription
# 0           1808  21-07-2015    tropical fruit
# 1           2552  05-01-2015        whole milk
# 2           2300  19-09-2015         pip fruit
# 3           1187  12-12-2015  other vegetables
# 4           3037  01-02-2015        whole milk

# %% [markdown]
# # Data Preparation

# %%
#Data Cleaning
myretaildata['itemDescription'] = myretaildata['itemDescription'].str.strip() #removes spaces from beginning and end
myretaildata.dropna(axis=0, subset=['Member_number'], inplace=True) #removes duplicate invoice
myretaildata['Member_number'] = myretaildata['Member_number'].astype('str') #converting invoice number to be string

myretaildata.head(10)
# Out:
#   Member_number        Date   itemDescription
# 0          1808  21-07-2015    tropical fruit
# 1          2552  05-01-2015        whole milk
# 2          2300  19-09-2015         pip fruit
# 3          1187  12-12-2015  other vegetables
# 4          3037  01-02-2015        whole milk
# 5          4941  14-02-2015        rolls/buns
# 6          4501  08-05-2015  other vegetables
# 7          3803  23-12-2015        pot plants
# 8          2762  20-03-2015        whole milk
# 9          4119  12-02-2015    tropical fruit

# %%
#graph of every item brought
myretaildata['itemDescription'].value_counts()
# Out:
# itemDescription
# whole milk               2502
# other vegetables         1898
# rolls/buns               1716
# soda                     1514
# yogurt                   1334
#                          ...
# rubbing alcohol             5
# bags                        4
# baby cosmetics              3
# kitchen utensil             1
# preservation products       1
# Name: count, Length: 167, dtype: int64

# %%
myretaildata['itemDescription'].value_counts()
myretaildata.shape
# Out:
# (38765, 3)

# %%
#grouping by of the columns
mybasket = (myretaildata.groupby(['Member_number', 'itemDescription'])['itemDescription'].count().unstack().reset_index().fillna(0).set_index('Member_number'))
mybasket.head()
drop
# Out:
# itemDescription  Instant food products  UHT-milk  abrasive cleaner  \
# Member_number
# 1000                               0.0       0.0               0.0
# 1001                               0.0       0.0               0.0
# 1002                               0.0       0.0               0.0
# 1003                               0.0       0.0               0.0
# 1004                               0.0       0.0               0.0
#
# itemDescription  artif. sweetener  baby cosmetics  bags  baking powder  \
# Member_number
# 1000                          0.0             0.0   0.0            0.0
# 1001                          0.0             0.0   0.0            0.0
# 1002                          0.0             0.0   0.0            0.0
# 1003                          0.0             0.0   0.0            0.0
# 1004                          0.0             0.0   0.0            0.0
#
# itemDescription  bathroom cleaner  beef  berries  ...  turkey  vinegar  \
# ...

# %%
#convert positve values to 1 and negeative values to 0.
def my_encode_units(x):
    if x <= 0:
        return 0
    if x >= 1:
        return 1

my_basket_sets = mybasket.map(my_encode_units)
my_basket_sets.head(10)
# Out:
# itemDescription  Instant food products  UHT-milk  abrasive cleaner  \
# Member_number
# 1000                                 0         0                 0
# 1001                                 0         0                 0
# 1002                                 0         0                 0
# 1003                                 0         0                 0
# 1004                                 0         0                 0
# 1005                                 0         0                 0
# 1006                                 0         0                 0
# 1008                                 0         0                 0
# 1009                                 0         0                 0
# 1010                                 0         1                 0
#
# itemDescription  artif. sweetener  baby cosmetics  bags  baking powder  \
# Member_number
# 1000                            0               0     0              0
# ...

# %% [markdown]
# # Training Model

# %%
#Generating frequent itemsets
my_frequent_itemsets = apriori(my_basket_sets, min_support=0.07, use_colnames=True)

#Generating Rules
my_rules = association_rules(my_frequent_itemsets, metric="lift", min_threshold=1)

#Viewing top 100 rules
my_rules.head(100)
#
# Out:
# /usr/local/lib/python3.11/dist-packages/mlxtend/frequent_patterns/fpcommon.py:161: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
#                        antecedents                     consequents  \
# 0                     (whole milk)                  (bottled beer)
# 1                   (bottled beer)                    (whole milk)
# 2                  (bottled water)              (other vegetables)
# 3               (other vegetables)                 (bottled water)
# 4                  (bottled water)                    (rolls/buns)
# ..                             ...                             ...
# 93      (yogurt, other vegetables)                    (whole milk)
# 94  (whole milk, other vegetables)                        (yogurt)
# 95                        (yogurt)  (whole milk, other vegetables)
# ...

# %% [markdown]
# # Making Recommendations

# %%
#maximum confidence and lift
my_rules['confidence'].max()
# Out:
# 0.5970149253731343

# %%
my_rules['lift'].max()
# Out:
# 1.3264336357824993

# %%
#filtering rules based on condition
my_rules[ (my_rules['lift'] >= 1.2) &
       (my_rules['confidence'] >= 0.5) ]
# Out:
#                        antecedents   consequents  antecedent support  \
# 88  (other vegetables, rolls/buns)  (whole milk)            0.146742
# 93      (yogurt, other vegetables)  (whole milk)            0.120318
#
#     consequent support   support  confidence      lift  representativity  \
# 88            0.458184  0.082093    0.559441  1.220996               1.0
# 93            0.458184  0.071832    0.597015  1.303003               1.0
#
#     leverage  conviction  zhangs_metric   jaccard  certainty  kulczynski
# 88  0.014859    1.229837       0.212124  0.157017   0.186884    0.369306
# 93  0.016704    1.344507       0.264348  0.141772   0.256233    0.376895
